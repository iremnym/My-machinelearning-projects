# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df=pd.read_csv("/kaggle/input/heart-attack-analysis-and-prediction-dataset/heart.csv")

# %%
df.head(3)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1

# %%
y=df['output']
x=df.drop("output",axis=1)

#x'in diğer yolu x=df.drop(columns=["outout"])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,train_size=0.7)

# %%
dt=DecisionTreeClassifier()
model=dt.fit(x,y)
model.score(x,y)
# Out:
# 1.0

# %%
dt=DecisionTreeClassifier()
model=dt.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.7252747252747253

# %%
rf=xgb.XGBClassifier()
model=rf.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8131868131868132

# %%
df.shape
# Out:
# (303, 14)

# %%
insan=df.sample().drop("output",axis=1).values
model.predict(insan)
#.values → Pandas DataFrame'i NumPy dizisine çeviriyor.
# Out:
# array([1])

# %% [markdown]
# *  array([1]) çıktısı, modelin tahmin ettiği sınıfın 1 olduğunu gösterir.
#
# Eğer model bir hastalık teşhisi modeli ise:
# 0 → "Hasta değil"
# 1 → "Hasta"
#
# Eğer model bir spam e-posta tespit modeli ise:
# 0 → "Spam değil"
# 1 → "Spam"
#
# Eğer model bir müşteri davranışı modeli ise:
# 0 → "Müşteri satın almaz"
# 1 → "Müşteri satın alır"
